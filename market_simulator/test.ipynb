# %%
import pandas as pd
from src.historical_feed import HistoricalFeed
from src.simulation_clock import SimulationClock
from datetime import datetime
from src.orderbook import Orderbook

# %%
clock = SimulationClock(start_time=datetime.now())
historical_feed = HistoricalFeed(clock)
historical_feed.load_messages()

# %%
orderbook = Orderbook()

# %%
historical_feed.replay(orderbook)
# Out:
# Orderbook processing message 2025-01-25 18:15:47.925000+01:00
# Orderbook processing change Side.SELL 0.23 300
# Orderbook processing message 2025-01-25 18:15:51.766000+01:00
# Orderbook processing change Side.SELL 0.31 5165
# Orderbook processing change Side.SELL 0.29 1601
# Orderbook processing change Side.SELL 0.3 13377
# Orderbook processing change Side.SELL 0.32 5246.77
# Orderbook processing message 2025-01-25 18:15:51.956000+01:00
# Orderbook processing change Side.SELL 0.32 5653.77
# Orderbook processing message 2025-01-25 18:15:52.152000+01:00
# Orderbook processing change Side.SELL 0.31 5064
# Orderbook processing change Side.SELL 0.3 13326
# Orderbook processing change Side.SELL 0.34 3128
# Orderbook processing change Side.SELL 0.32 5552.77
# Orderbook processing change Side.SELL 0.29 1550
# Orderbook processing change Side.SELL 0.24 4091.48
# Orderbook processing change Side.SELL 0.33 4933
# Orderbook processing message 2025-01-25 18:15:52.277000+01:00
# ...
